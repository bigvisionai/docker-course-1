# %% [markdown]
# # Course 1 Docker image
#
# Check out our courses at [opencv.org/courses](https://www.opencv.org/courses)
# <br>
# This is a sample notebook to demonstrate how to write cpp code in Python Jupyter Notebooks.
#
# You can create and share documents that contain live code, equations, visualizations and narrative text using these notebooks.
#
# You can code in it like a normal python code file

# %% [markdown]
# First we print the Python version

# %%
import sys
print("Python version: "+sys.version)
# Out:
# Python version: 3.7.7 (default, May  7 2020, 21:25:33)
# [GCC 7.3.0]

# %% [markdown]
# This is the numpy version which we have installed. This was necessary for the OpenCV installation

# %%
import numpy
print("Numpy version: "+numpy.__version__)
# Out:
# Numpy version: 1.19.1

# %% [markdown]
# We have installed the latest OpenCV version at the time of this docker image creation

# %%
import cv2 as cv
print("OpenCV version: "+cv.__version__)
# Out:
# OpenCV version: 4.4.0

# %% [markdown]
# Notebooks are great for creating code documents, but you cannot use high-gui functionalities of OpenCV on the Notebook.
#
# To print images in the notebook, we can use `matplotlib`.

# %%
import matplotlib
import matplotlib.pyplot as plt
print("MatPlotLib version: "+matplotlib.__version__)
# Out:
# MatPlotLib version: 3.3.0

# %% [markdown]
# The following code block will help you demonstrate how to read, and print images in the notebook.

# %%
img=cv.imread("../Extras/Quick_brown_fox.png", -1);
plt.axis("off")
plt.imshow(cv.cvtColor(img, cv.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# If you need any other package, you can `pip install <package>` in the terminal and use it in the notebook.
#
# If you install any package, the changes will not be saved if you destroy the container. The package exists until the container exists.
